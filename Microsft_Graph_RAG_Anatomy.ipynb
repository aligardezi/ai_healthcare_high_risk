# %% [markdown]
# #Summary

# %% [markdown]
# This notebook contains instructions on how to setup Microsoft GraphRAG, load a medical text book and then ask questions against that text book.
#
# *   Setup Micosoft GraphRAG
# *   Load Anatomy text book
# *   Ask questions from an Anatomy question set
#
# The Anatomy book is sourced from https://huggingface.co/datasets/MedRAG/textbooks
#
# The question set is sourced from https://github.com/Teddy-XiongGZ/MIRAGE/blob/main/rawdata/mmlu/data/test/anatomy_test.csv

# %% [markdown]
# # Install Graph RAG

# %%
! pip install graphrag
# Out:
# Collecting graphrag
#   Downloading graphrag-0.5.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiofiles<25.0.0,>=24.1.0 (from graphrag)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiolimiter<2.0.0,>=1.1.0 (from graphrag)
#   Downloading aiolimiter-1.2.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting azure-identity<2.0.0,>=1.17.1 (from graphrag)
#   Downloading azure_identity-1.19.0-py3-none-any.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.0 MB/s eta 0:00:00
# Collecting azure-search-documents<12.0.0,>=11.4.0 (from graphrag)
#   Downloading azure_search_documents-11.5.2-py3-none-any.whl.metadata (23 kB)
# Collecting azure-storage-blob<13.0.0,>=12.22.0 (from graphrag)
#   Downloading azure_storage_blob-12.24.0-py3-none-any.whl.metadata (26 kB)
# Collecting datashaper<0.0.50,>=0.0.49 (from graphrag)
#   Downloading datashaper-0.0.49-py3-none-any.whl.metadata (3.7 kB)
# Collecting devtools<0.13.0,>=0.12.2 (from graphrag)
#   Downloading devtools-0.12.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting environs<12.0.0,>=11.0.0 (from graphrag)
#   Downloading environs-11.2.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: future<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.0.0)
# Collecting graspologic<4.0.0,>=3.4.1 (from graphrag)
#   Downloading graspologic-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting json-repair<0.31.0,>=0.30.0 (from graphrag)
#   Downloading json_repair-0.30.2-py3-none-any.whl.metadata (11 kB)
# Collecting lancedb<0.14.0,>=0.13.0 (from graphrag)
#   Downloading lancedb-0.13.0-cp38-abi3-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Collecting matplotlib<4.0.0,>=3.9.0 (from graphrag)
#   Downloading matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: networkx<4,>=3 in /usr/local/lib/python3.10/dist-packages (from graphrag) (3.4.2)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.10/dist-packages (from graphrag) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.51.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (1.54.4)
# Collecting pandas<3.0.0,>=2.2.3 (from graphrag)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.8 MB/s eta 0:00:00
# Collecting pyaml-env<2.0.0,>=1.2.1 (from graphrag)
#   Downloading pyaml_env-1.2.1-py3-none-any.whl.metadata (12 kB)
# Collecting pyarrow<16.0.0,>=15.0.0 (from graphrag)
#   Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (2.9.2)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from graphrag)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (6.0.2)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (13.9.4)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from graphrag) (9.0.0)
# Collecting tiktoken<0.8.0,>=0.7.0 (from graphrag)
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typer<0.13.0,>=0.12.5 (from graphrag)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from graphrag) (4.12.2)
# Collecting umap-learn<0.6.0,>=0.5.6 (from graphrag)
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk==3.9.1->graphrag) (4.66.6)
# Collecting azure-core>=1.31.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading azure_core-1.32.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.10/dist-packages (from azure-identity<2.0.0,>=1.17.1->graphrag) (43.0.3)
# Collecting msal>=1.30.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal-1.31.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting azure-common>=1.1 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting isodate>=0.6.0 (from azure-search-documents<12.0.0,>=11.4.0->graphrag)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting diskcache<6.0.0,>=5.6.3 (from datashaper<0.0.50,>=0.0.49->graphrag)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.21.1 in /usr/local/lib/python3.10/dist-packages (from datashaper<0.0.50,>=0.0.49->graphrag) (4.23.0)
# Collecting asttokens<3.0.0,>=2.0.0 (from devtools<0.13.0,>=0.12.2->graphrag)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting executing>=1.1.1 (from devtools<0.13.0,>=0.12.2->graphrag)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pygments>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from devtools<0.13.0,>=0.12.2->graphrag) (2.18.0)
# Collecting marshmallow>=3.13.0 (from environs<12.0.0,>=11.0.0->graphrag)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting POT<0.10,>=0.9 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading POT-0.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting anytree<3.0.0,>=2.12.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting beartype<0.19.0,>=0.18.5 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading beartype-0.18.5-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: gensim<5.0.0,>=4.3.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (4.3.3)
# Collecting graspologic-native<2.0.0,>=1.2.1 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading graspologic_native-1.2.1-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting hyppo<0.5.0,>=0.4.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading hyppo-0.4.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (1.5.2)
# Collecting scipy==1.12.0 (from graspologic<4.0.0,>=3.4.1->graphrag)
#   Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (0.13.2)
# Requirement already satisfied: statsmodels<0.15.0,>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from graspologic<4.0.0,>=3.4.1->graphrag) (0.14.4)
# Collecting deprecation (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pylance==0.17.0 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading pylance-0.17.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (2.32.3)
# Collecting retry>=0.9.2 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (24.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (24.2)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from lancedb<0.14.0,>=0.13.0->graphrag) (5.5.0)
# Collecting overrides>=0.7 (from lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (1.4.7)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.9.0->graphrag) (2.8.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.51.2->graphrag) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.51.2->graphrag) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.51.2->graphrag) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.51.2->graphrag) (0.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.51.2->graphrag) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.2.3->graphrag) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.2.3->graphrag) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.9.2->graphrag) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->graphrag) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->graphrag) (1.5.4)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn<0.6.0,>=0.5.6->graphrag) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn<0.6.0,>=0.5.6->graphrag)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.51.2->graphrag) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.51.2->graphrag) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from anytree<3.0.0,>=2.12.1->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (1.17.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (7.0.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.51.2->graphrag) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.51.2->graphrag) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.51.2->graphrag) (0.14.0)
# Requirement already satisfied: autograd>=1.3 in /usr/local/lib/python3.10/dist-packages (from hyppo<0.5.0,>=0.4.0->graspologic<4.0.0,>=3.4.1->graphrag) (1.7.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema<5.0.0,>=4.21.1->datashaper<0.0.50,>=0.0.49->graphrag) (0.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->graphrag) (0.1.2)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity<2.0.0,>=1.17.1->graphrag) (2.10.0)
# Collecting portalocker<3,>=1.4 (from msal-extensions>=1.2.0->azure-identity<2.0.0,>=1.17.1->graphrag)
#   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn<0.6.0,>=0.5.6->graphrag) (0.43.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->lancedb<0.14.0,>=0.13.0->graphrag) (2.2.3)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.10/dist-packages (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag) (4.4.2)
# Collecting py<2.0.0,>=1.4.26 (from retry>=0.9.2->lancedb<0.14.0,>=0.13.0->graphrag)
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.4.2->graspologic<4.0.0,>=3.4.1->graphrag) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels<0.15.0,>=0.14.2->graspologic<4.0.0,>=3.4.1->graphrag) (1.0.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity<2.0.0,>=1.17.1->graphrag) (2.22)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim<5.0.0,>=4.3.2->graspologic<4.0.0,>=3.4.1->graphrag) (1.16.0)
# Downloading graphrag-0.5.0-py3-none-any.whl (406 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 406.3/406.3 kB 15.6 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading aiolimiter-1.2.0-py3-none-any.whl (6.3 kB)
# Downloading azure_identity-1.19.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.6/187.6 kB 15.3 MB/s eta 0:00:00
# Downloading azure_search_documents-11.5.2-py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 22.5 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.24.0-py3-none-any.whl (408 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 30.1 MB/s eta 0:00:00
# Downloading datashaper-0.0.49-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.3 MB/s eta 0:00:00
# Downloading devtools-0.12.2-py3-none-any.whl (19 kB)
# Downloading environs-11.2.1-py3-none-any.whl (12 kB)
# Downloading graspologic-3.4.1-py3-none-any.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 79.8 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.4/38.4 MB 47.8 MB/s eta 0:00:00
# Downloading json_repair-0.30.2-py3-none-any.whl (18 kB)
# Downloading lancedb-0.13.0-cp38-abi3-manylinux_2_28_x86_64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 81.2 MB/s eta 0:00:00
# Downloading pylance-0.17.0-cp39-abi3-manylinux_2_28_x86_64.whl (29.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 64.0 MB/s eta 0:00:00
# Downloading matplotlib-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 94.0 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 72.0 MB/s eta 0:00:00
# Downloading pyaml_env-1.2.1-py3-none-any.whl (9.0 kB)
# Downloading pyarrow-15.0.2-cp310-cp310-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 38.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.6 MB/s eta 0:00:00
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.8 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 7.6 MB/s eta 0:00:00
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.5 MB/s eta 0:00:00
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 16.0 MB/s eta 0:00:00
# Downloading beartype-0.18.5-py3-none-any.whl (917 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 917.8/917.8 kB 51.6 MB/s eta 0:00:00
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.5 MB/s eta 0:00:00
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading graspologic_native-1.2.1-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.7 MB/s eta 0:00:00
# Downloading hyppo-0.4.0-py3-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.6/146.6 kB 12.5 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.0 MB/s eta 0:00:00
# Downloading msal-1.31.1-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.2/113.2 kB 9.8 MB/s eta 0:00:00
# Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading POT-0.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (865 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.6/865.6 kB 54.8 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.9 MB/s eta 0:00:00
# Downloading retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: azure-common, scipy, python-dotenv, pyarrow, pyaml-env, py, portalocker, overrides, marshmallow, json-repair, isodate, graspologic-native, executing, diskcache, deprecation, beartype, asttokens, anytree, aiolimiter, aiofiles, tiktoken, retry, pylance, POT, pandas, matplotlib, environs, devtools, azure-core, typer, pynndescent, lancedb, hyppo, azure-storage-blob, azure-search-documents, umap-learn, msal, datashaper, msal-extensions, graspologic, azure-identity, graphrag
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.13.0
#     Uninstalling typer-0.13.0:
#       Successfully uninstalled typer-0.13.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed POT-0.9.5 aiofiles-24.1.0 aiolimiter-1.2.0 anytree-2.12.1 asttokens-2.4.1 azure-common-1.1.28 azure-core-1.32.0 azure-identity-1.19.0 azure-search-documents-11.5.2 azure-storage-blob-12.24.0 beartype-0.18.5 datashaper-0.0.49 deprecation-2.1.0 devtools-0.12.2 diskcache-5.6.3 environs-11.2.1 executing-2.1.0 graphrag-0.5.0 graspologic-3.4.1 graspologic-native-1.2.1 hyppo-0.4.0 isodate-0.7.2 json-repair-0.30.2 lancedb-0.13.0 marshmallow-3.23.1 matplotlib-3.9.3 msal-1.31.1 msal-extensions-1.2.0 overrides-7.7.0 pandas-2.2.3 portalocker-2.10.1 py-1.11.0 pyaml-env-1.2.1 pyarrow-15.0.2 pylance-0.17.0 pynndescent-0.5.13 python-dotenv-1.0.1 retry-0.9.2 scipy-1.12.0 tiktoken-0.7.0 typer-0.12.5 umap-learn-0.5.7

# %% [markdown]
# # Initialize the Graph RAG Workspace

# %%
! graphrag init --root ./ragtest
# Out:
# Initializing project at /content/ragtest
# ⠋ GraphRAG Indexer

# %% [markdown]
# # Create folder for input files

# %%
import os

os.makedirs("ragtest/input", exist_ok=True)

# %% [markdown]
# # Update your settings.yaml file

# %% [markdown]
# *   Got to the ./ragtest folder and open settings.yaml
# *   Update all instances of api_key with your api key from OpenAI
# *   Update the LLM model to one you have access to from OpenAI. For this task I used gpt-4o
# *   Update the embedding LLM model to one you have access to from OpenAI. For this task I used text-embedding-small

# %% [markdown]
# # Create the knowledge Graph

# %%
! graphrag index --root ./ragtest
# Out:
# Streaming output truncated to the last 5000 lines.
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ...
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠹ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# 🚀 generate_text_embeddings
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# Empty DataFrame
# Columns: []
# Index: []
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (text) - 3017 files loaded (0 filtered) ━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ├── create_base_text_units
# ├── create_final_documents
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── create_final_relationships
# ├── create_final_text_units
# ├── create_final_community_reports
# └── generate_text_embeddings
# 🚀 All workflows completed successfully.

# %% [markdown]
# # View the Communities

# %%
import pandas as pd

file_path = './ragtest/output/create_final_communities.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 12950
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # View the Community Reports

# %%
import pandas as pd

file_path = '/content/ragtest/output/create_final_community_reports.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 16848

# %% [markdown]
# # View the documents

# %%
import pandas as pd

file_path = '/content/ragtest/output/create_final_documents.parquet'
df = pd.read_parquet(file_path)
df["title"].unique().size
# Out:
# 3017

# %% [markdown]
# # View the entities

# %%
import pandas as pd

file_path = './ragtest/output/create_final_entities.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 35652

# %% [markdown]
# # View the nodes

# %%
import pandas as pd

file_path = '/content/ragtest/output/create_final_nodes.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 139488

# %% [markdown]
# # View the relationships

# %%
import pandas as pd

file_path = './ragtest/output/create_final_relationships.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 85968

# %% [markdown]
# # View text units

# %%
import pandas as pd

file_path = '/content/ragtest/output/create_final_text_units.parquet'
df = pd.read_parquet(file_path)
df.size
# Out:
# 21119

# %% [markdown]
# # Global Queries

# %%
! graphrag query --root ./ragtest --method global --query "What is Anatomy? A - Study of the Body. B - Study of Animals. C - Study of Finance"
# Out:
# creating llm client with {'api_key': 'REDACTED,len=164', 'type': "openai_chat", 'model': 'gpt-4o', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Global Search Response:
# ### Understanding Anatomy
#
# Anatomy is the study of the human body and its structure. It is a foundational discipline that is crucial for various healthcare professions. This field provides essential knowledge for understanding the human body, which is vital for medical education and practice [Data: Reports (0)].
#
# ### Conclusion
#
# Based on the provided information, the correct answer is **A - Study of the Body**. Anatomy focuses specifically on the human body, distinguishing it from other fields such as zoology, which studies animals, or finance, which deals with economic systems.

# %% [markdown]
# # Local  Queries

# %%
! graphrag query --root ./ragtest --method local --query "What is a LINGUAL ARTERY?"
# Out:
# INFO: Vector Store Args: {
#     "type": "lancedb",
#     "db_uri": "/content/ragtest/output/lancedb",
#     "container_name": "==== REDACTED ====",
#     "overwrite": true
# }
# creating llm client with {'api_key': 'REDACTED,len=164', 'type': "openai_chat", 'model': 'gpt-4o', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=164', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'audience': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Local Search Response:
# ## Lingual Artery Overview
#
# The lingual artery is a significant blood vessel that plays a crucial role in the circulatory system of the head and neck. It is a branch of the external carotid artery, which is a major artery in the neck responsible for supplying blood to the face and neck regions [Data: Entities (2, 1); Relationships (2)]. The lingual artery specifically supplies blood to the tongue, which is a muscular organ in the mouth [Data: Entities (2, 5); Relationships (5)].
#
# ## Anatomical Pathway
#
# The lingual artery originates from the external carotid artery and courses through the neck. It eventually terminates in the tongue, providing it with the necessary blood supply for its functions [Data: Entities (2, 5); Relationships (4, 5)]. This pathway highlights the importance of the lingual artery in maintaining the health and functionality of the tongue.
#
# ## Clinical Significance
#
# Understanding the anatomy of the lingual artery is essential for medical professionals, particularly in fields such as surgery and dentistry. Knowledge of its course and connections is crucial for procedures involving the tongue and surrounding areas. Additionally, the lingual artery's role in supplying blood to the tongue makes it a vital component in the overall vascular system of the head and neck.
#
# In summary, the lingual artery is a vital artery that branches from the external carotid artery to supply blood to the tongue, playing a key role in the vascular system of the head and neck.

# %%
import os

os.makedirs("anatomy_questions", exist_ok=True)

# %% [markdown]
# # Create Question files from the anatomy test csv

# %%
# read the test csv file
# file sourced from https://github.com/Teddy-XiongGZ/MIRAGE/blob/main/rawdata/mmlu/data/test/anatomy_test.csv

import pandas as pd

# Specify the file path
file_path = "anatomy_test.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, header=None)

for index, row in df.iterrows():
    # Convert the row to a DataFrame
    row_df = pd.DataFrame([row])

    # Save the row as a CSV file
    output_file = f"anatomy_questions/test_anatomy-question_{index:03}.txt"  # Adjust filename as needed

    with open(output_file, "w") as f:
        f.write(row[0] + "\n\n")
        f.write("A. " + row[1] + "\n")
        f.write("B. " + row[2] + "\n")
        f.write("C. " + row[3] + "\n")
        f.write("D. " + row[4])

# %% [markdown]
# # Ask Anatomy Questions from GraphRAG

# %%
import os

os.makedirs("anatomy_answers", exist_ok=True)

# %%
import subprocess
import os

# Define the directory path
directory_path = "./anatomy_questions"
output_directory = "./anatomy_answers"

# Loop through each file in the directory
for file_name in os.listdir(directory_path):
    file_path = os.path.join(directory_path, file_name)
    output_file_path = os.path.join(output_directory, file_name)
    # Check if it's a file
    if os.path.isfile(file_path):
        with open(file_path, 'r') as file:
            question = file.read()
            answer = subprocess.run("graphrag query \
            --root ./ragtest \
            --method local \
            --query \"" + question +"\" > " + output_file_path, shell=True, capture_output=True, text=True)

# %% [markdown]
# # Compare Answers between GraphRAG and Question Key

# %%
# compare the answers
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.expand_frame_repr', False)


source = pd.read_csv("./anatomy_test.csv", header=None)
answer_key = source.iloc[:,5]
graph_rag_answers = pd.read_csv("./anatomy_answers_graph_rag/answers.csv")
graph_rag_answers = graph_rag_answers.replace(np.nan, '', regex=True)
graph_rag_answer_key = graph_rag_answers.iloc[:,1]
new_df = pd.DataFrame({'correct_answer': answer_key, 'graph_rag_answer': graph_rag_answer_key})
new_df['is_graph_rag_answer_correct'] = new_df['correct_answer'] == new_df['graph_rag_answer']
new_df['graph_rag_answer_comment'] = graph_rag_answers['Comments']
correct_count = new_df['is_graph_rag_answer_correct'].sum()
print(correct_count)
new_df.to_csv('./graph_rag_answers_comparison_to_answer_key.csv', index=False)
# Out:
# 114
